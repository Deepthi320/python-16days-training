# %%
#xor operator
a=0b101100
b=0b100101
c=a^b
print(bin(c))
# Out:
# 0b1001

# %%
#not opeerator
#inverse the values
b = 0b100101
c = ~b
print(bin(c))
# Out:
# -0b100110

# %%
a=0b10100
b=a << 2 #(2*2)
print(int(b))
# Out:
# 80

# %%
a=0b10100
b=a << 3 #(2*2)
print(int(b))
# Out:
# 160

# %%
bin(640)
# Out:
# '0b1010000000'

# %%
a =0b1010000000
b=a >> 0 #()
print(int(b))
# Out:
# 640

# %%
a =0b1010000000
b=a >> 1 #(2/640)
print(int(b))
# Out:
# 320

# %%
a =0b1010000000
b=a >> 2 #(2*2/640)
print(int(b))
# Out:
# 160

# %%
#converting string to upper case
s='A'

result = chr(ord(s) + 32)

# %%
a=1
b=30
print(a+b)
# Out:
# 31

# %%
n1 = int(input('enter a num:'))
n2 = int(input('enter a num:'))
result = n1+n2
result
# Out:
# enter a num: 20
# enter a num: 30
# 50

# %%
n1 = int(input('enter a num:'))

bool (n1 % 2 == 0)
# Out:
# enter a num: 23
# False

# %%
num = '9390669648'
num[8:10]
# Out:
# '48'
