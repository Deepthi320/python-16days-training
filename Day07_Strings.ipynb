# %%
#strings
#if we use print it removes quotes
s='python'
s
# Out:
# 'python'

# %%
s='python is programming language'
s
# Out:
# 'python is programming language'

# %%
s='"python" is programming language'
print(s)
# Out:
# "python" is programming language

# %%
#\n-> is for line break
s='"python" is\nprogramming language'
print(s)
# Out:
# "python" is
# programming language

# %%
#/t->gives Tab space
s='"python" is\tprogramming language'
print(s)
# Out:
# "python" is	programming language

# %%
#/b->backspace removes one letter
s='"python" is\b programming language'
print(s)
# Out:
# "python" i programming language

# %%
#Formatting strings
#syntax: f""-->{variable}--> modify
student='Rahul'
course='DATA SCIENCE'
fee= 90000

print(f'he is {student} he enrolled in course:{course} with fee:{fee} with discount:{fee*0.1}')
# Out:
# he is Rahul he enrolled in course:DATA SCIENCE with fee:90000 with discount:9000.0

# %%
#Indexing and Slicing:
#two typs of indexing:-
#Positive(starts from 0) and Negative(starts from -1)

s='DATASCIENCE'
s[-5]
# Out:
# 'I'

# %%
#slicing
#parameters:strat,stop,step
#step->decides the direction
s[0::1]
# Out:
# 'DATASCIENCE'

# %%
s[0:-4:]
# Out:
# 'DATASCI'

# %%
s[-3:0:-1]
# Out:
# 'NEICSATA'

# %%
s='datascience deepthi'
for i in range(1,len(s),2):
    print(s[i],end=' ')
# Out:
# a a c e c   e p h

# %%
s='1234'
len(s)
# Out:
# 4

# %%
len(str(1234))
# Out:
# 4

# %%
#Methods
#6 IMP Case Related Methods:
a='pYTHON pRogramming'
print(a.lower())
print(a.upper())
# Out:
# python programming
# PYTHON PROGRAMMING

# %%
a='python programming'
print(a.title())# every word first letter as capital
print(a.capitalize())#in sentence first letter as capital
# Out:
# Python Programming
# Python programming

# %%
s='HEllo World'
print(s.swapcase())#oppsite of given case
print(s.casefold())#irrespective gives only in lower case->(lower())
# Out:
# heLLO wORLD
# hello world

# %%
#3 Adjusting Methods:
text="python"
print(text.center(20,"*"))
print(text.ljust(20,"-"))
print(text.rjust(20,"&"))
# Out:
#        python
# python--------------
# &&&&&&&&&&&&&&python

# %%
#3 Adjusting Methods->example
text="Welcome To Bitm"
print(text.center(40," "))
print(text.ljust(20,"*"))
print(text.rjust(30,"^"))
# Out:
#             Welcome To Bitm
# Welcome To Bitm*****
# ^^^^^^^^^^^^^^^Welcome To Bitm

# %%
s='Python Programming'
#FIND & INDEX both gives index values
print(s.find("pro"))#if thr value is not present it gives -1.
print(s.index("P"))#if the value is not present it throws an error.
print(s.count("o"))#it counts how many times the character present if not present it gives ZERO.
print(s.startswith("Py"))
print(s.endswith("ing"))
# Out:
# -1
# 0
# 2
# True
# True

# %%
s="python programming"
count=0
for ch in s:
    if ch.lower() in 'aeiou':
        count+=1

print(count)
# Out:
# 4

# %%
s="python pro564737gramming464647"
count=0
for num in s:
    if num in '0123456789':
        count+=1

print(count)
# Out:
# 12

# %%
#Ascii values:
print(ord('0'))
print(ord('9'))
# Out:
# 48
# 57

# %%
s="python pro564737gramming464647"
count=0
sum=0
for ch in s:
    if ch in s:
        ascii=ord(ch)
        if ascii >=48 and ascii <=57:
            count+=1
            sum=sum+count

print(count)
print(sum)
# Out:
# 12
# 78

# %%
print("1deepthi".islower())
print("DEEPTHI".isupper())
print("Deepthi".istitle())
print("123".isdigit())
print("abc123".isalnum())
print("abc".isalpha())
print("  ".isspace())
print("variable_name".isidentifier())
print("print".isprintable())
print("10".isdecimal())
print("123".isnumeric())
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
s="python is powerful"
#s.split("@")[1]-->for example email's
print(s.split())
print(s.split("i"))
print(s.rsplit(" ",1))
print("line1\nline2".splitlines()) #split by line

l=['india','usa','germany']
':'.join(l)
# Out:
# ['python', 'is', 'powerful']
# ['python ', 's powerful']
# ['python is', 'powerful']
# ['line1', 'line2']
# 'india:usa:germany'

# %%
#replace->('old','new')
s= "sudha is girl"
s.replace('girl','boy')
# Out:
# 'sudha is boy'

# %%
s="I like java"

print(s.replace("java","python"))
print("   hello   ".strip())#whiteSpaces(tryingSpaces)
print("   hello   ".lstrip())
print("   hello   ".rstrip())
# Out:
# I like python
# hello
# hello
#    hello

# %%
#convert a given string to uppercase using a string method.
#convert a given string to lowercase using a string method.
#Count how many times the letter 'a' appears in a string.
#Check whether a given string starts with "hello"
#Check whether a given string ends with ".com"
#Replace all spaces in a string with underscores(_)
#Remove leading and trailing spaces from a string.
#find the index position of the first occurence of "python" in a string.
#check whether a string contains only digits.
#check whether a string contains only alphabets.
#Convert the first letter of a string into uppercase(capitalize the string)
#Split a sentence into a list of words.
#Join a list of words into a single string separated by commas.
#Count the total number of characters in a string(excluding spaces)
#Swap uppercase letters to lowercase and lowercase letters to upppercase.
#Find how many words are present in a sentence.
#Replace a specific word in a sentence with another word.
#Check whether all characters in a string are lowercase.
#Format a string to insert a name and age into a sentence using formatting

# %%
s="Ballari"
print(s.upper())
print(s.lower())
# Out:
# BALLARI
# ballari

# %%
s="hello python programming"
print(s.count(' '))
print(s.startswith("hello"))
print(s.endswith(".com"))
# Out:
# 2
# True
# False

# %%
#replace->('old','new')
s= "sudha is girl"
s.replace(' ','_')
# Out:
# 'sudha_is_girl'

# %%
print("   hello   ".strip())
print("   hello   ".lstrip())
print("   hello   ".rstrip())
# Out:
# hello
# hello
#    hello

# %%
s='Python'

print(s.index("P"))
# Out:
# 0

# %%
print("123".isdigit())
print("abc".isalpha())
# Out:
# True
# True

# %%
a='python programming'
print(a.capitalize())#in sentence first letter as capital
# Out:
# Python programming

# %%
s='deepthi is a good girl'
print(s.split())
# Out:
# ['deepthi', 'is', 'a', 'good', 'girl']

# %%
l=['india','usa','germany']
' '.join(l)
# Out:
# 'india usa germany'

# %%
s="python pro5647 37gram ming464647"
total=s.replace(" ","")
count=len(total)
print(count)
# Out:
# 29

# %%
s='HEllo World'
print(s.swapcase())
# Out:
# heLLO wORLD

# %%
#replace->('old','new')
s= "deepak is a girl"
s.replace('girl','boy')
# Out:
# 'deepak is a boy'

# %%
print("pYthon".islower())
# Out:
# False

# %%
s="python is powerful"

print(s.split())
total_words=s.split()
print(len(total_words))
# Out:
# ['python', 'is', 'powerful']
# 3

# %%
name="Divya"
age=80

print(f"My name is {name} my age is {age}.")
# Out:
# My name is Divya my age is 80.

# %%
#create a validation password which is having len more than 8,uppercase,lowecase,special characters,digits...
def valide_password(password):

    if len(password) <= 8:
        return "Password must be more than 8 characters"

    upper = False
    lower = False
    digit = False
    special = False

    special_chars = "@#$%^&*()-_=+{}[]/?.,><"

    for char in password:
        if char.isupper():
            upper = True
        elif char.islower():
            lower = True
        elif char.isdigit():
            digit = True
        elif char in special_chars:
            special = True

    if not upper:
        return "Password must contain at least one uppercase letter"
    if not lower:
        return "Password must contain at least one lowercase letter"
    if not digit:
        return "Password must contain at least one digit"
    if not special:
        return "Password must contain at least one special character"

    return "Password is valid"


password = input("Enter a password: ")
print(valide_password(password))
# Out:
# Enter a password:  valiD_1245
# Password is valid
